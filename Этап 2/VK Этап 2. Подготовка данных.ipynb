# %%
import pandas as pd
import numpy as np

# %%
db = pd.read_excel('dataset.xlsx')
db = db[db.columns.drop(list(db.filter(regex='^Unnamed')))]

# %% [markdown]
# # Есть возможность преобразовать какие-то столбцы с данными в уникальные идентификаторы, чтобы не хранить избыточную информацию. Также создать таблицу справочник для сопоставления id к информации.

# %% [markdown]
# ## Для начала преобразуем department в id и создадим таблицу справочник

# %%
unique_deps = list(set(db['department']))
deps_ds = pd.DataFrame(list(zip(range(len(unique_deps)), unique_deps)), columns =['dep_id', 'department'])
db = pd.merge(db, deps_ds, how='inner', on = 'department')

# %% [markdown]
# ## Аналогично можно с hometown, однако там нет унифицированной информации. Данные об одном месте могут называться по-разному. Если и обрабатывать данные, то явно другим способом. Пример разных названий:

# %%
print(db['hometown'][0])
print(db['hometown'][1])
print(db['hometown'][26528])
# Out:
#  ГОР. КАЗАНЬ
#  РОССИЯ ГОР. КАЗАНЬ
#  423057, РОССИЯ, РЕСП. ТАТАРСТАН (ТАТАРСТАН), АКСУБАЕВСКИЙ Р-Н, С. НОВОЕ ДЕМКИНО

# %% [markdown]
# ## Изменим дату рождения. Есть строки, которые не содержат дат, нужно их почистить и оставить только подходящие.

# %%
db['birthday']=db['birthday'].str.replace('.','')

# %%
db['birthday'] = db['birthday'].astype(str)
db['birthday_digit'] = list(map(lambda x: x.isdigit(), db['birthday']))

# %%
print('Количество строк с цифрами {}. Количество строк без цифр {}'
      .format(len(db[db['birthday_digit'] == True]), len(db[db['birthday_digit'] == False])))
# Out:
# Количество строк с цифрами 26441. Количество строк без цифр 92

# %%
db['birthday'] = db[db['birthday_digit'] == True]['birthday']
db['birthday'] = pd.to_datetime(db['birthday'], format='%d%m%Y')

# %% [markdown]
# ## number_ip можно разбить на уникальный идентификатор и дату
# ## из поля details можно выявить какие-то уникальные слова
# ## из поля credit можно получить тип задолжености и сумму исполнительного сбора

# %%
db['credit'] = db['credit'].astype(str)
for i in range(len(db)):
    # получение id, даты и года исполнительного производства
    arr = db['number_ip'][i].split(' ')
    db.loc[i, 'number_ip_id'] = arr[0]
    db.loc[i, 'number_ip_date'] = arr[2]
    arr = db['number_ip_date'][i].split('.')
    db.loc[i, 'year'] = arr[2]
    
    # получение уникальных значений описания "на коленке)"
    splt = db['details'][i].split(' ')
    db.loc[i, 'uniq_details'] = splt[0] + ' ' + splt[1]
    
    # получение уникальных значений по типу задолженности    
    arr = db['credit'][i].split(': ')
    db.loc[i, 'credit_type'] = arr[0]
    if len(arr) > 1:
        if ('Исполнительский сбор' in arr[1]):
            db.loc[i, 'sum_rub'] = arr[1].split(' ')[0]
            if len(arr) == 3:
                db.loc[i, 'ip_sum'] = arr[2].split()[0]

# %% [markdown]
# ## Преобразуем поле статус в типы статуса, для этого проделаем некоторые преобразования по приведению к стандартному виду и созданию типов на этих стандартах

# %%
print('как выглядело до')
db['status']
# Out:
# как выглядело до
# 0        2020-03-18, 46, 1, 3
# 1                         NaN
# 2        2020-10-19, 46, 1, 3
# 3        2020-01-20, 46, 1, 3
# 4        2019-01-17, 46, 1, 3
#                  ...
# 26528                     NaN
# 26529                     NaN
# 26530    2018-05-17, 46, 1, 3
# 26531                     NaN
# 26532                     NaN
# Name: status, Length: 26533, dtype: object

# %%
db['status'] = db['status'].str[12:] 
db['status'] = db['status'].replace(np.nan, '0')
db['status'] = db['status'].replace('', '0')
print('как выглядело после')
db['status']
# Out:
# как выглядело после
# 0        46, 1, 3
# 1               0
# 2        46, 1, 3
# 3        46, 1, 3
# 4        46, 1, 3
#            ...
# 26528           0
# 26529           0
# 26530    46, 1, 3
# 26531           0
# 26532           0
# Name: status, Length: 26533, dtype: object

# %%
# стандартизируем и джойним к основной таблице
unique_status = list(set(db['status']))
status_ds = pd.DataFrame(list(zip(range(len(unique_status)), unique_status)), columns =['status_id', 'status'])
db = pd.merge(db, status_ds, how='inner', on = 'status')
db
# Out:
#           name     lastname     secondname   birthday  \
# 0         ЕГОР        РОГОВ     НИКОЛАЕВИЧ 1985-07-31
# 1       РАМИЛЬ       ГАЙСИН     РОБЕРТОВИЧ 1993-05-19
# 2       ГУЗЕЛЬ     ГАЛИМОВА      КАМИЛЕВНА 1990-09-01
# 3       ГУЗЕЛЬ     ГАЛИМОВА      КАМИЛЕВНА 1990-09-01
# 4       ГУЗЕЛЬ     ГАЛИМОВА      КАМИЛЕВНА 1990-09-01
# ...        ...          ...            ...        ...
# 26528    МАРАТ  ГАЛЯУТДИНОВ      РЕНАТОВИЧ 1992-01-24
# 26529    ИГОРЬ      МОРОЗОВ  АЛЕКСАНДРОВИЧ 1983-09-28
# 26530  ТАТЬЯНА      ПЕТРОВА    ГЕННАДЬЕВНА 1985-01-12
# 26531    ЛЕНАР     МУРТАЗИН      РИНАТОВИЧ 1968-03-30
# 26532    ЛЕНАР     МУРТАЗИН      РИНАТОВИЧ 1968-03-30
#
#                                                 hometown  \
# 0                                            ГОР. КАЗАНЬ
# 1                                              Г. КАЗАНЬ
# 2                                              Г. КАЗАНЬ
# 3                                              Г. КАЗАНЬ
# 4                                              Г. КАЗАНЬ
# ...                                                  ...
# 26528                           РЕСП. ТАТАРСТАН, Г. АРСК
# 26529   РОССИЯ, РЕСП. ТАТАРСТАН (ТАТАРСТАН), АКСУБАЕВ...
# 26530              САМАРСКАЯ ОБЛ., С. БОЛЬШАЯ ЧЕРНИГОВКА
# 26531                                        ГОР. КАЗАНЬ
# 26532                                   СССР ГОР. КАЗАНЬ
#
#                               number_ip  \
# 0      129954/19/16007-ИП от 23.12.2019
# 1        9013/20/16007-ИП от 03.02.2020
# 2       60056/17/16007-ИП от 03.10.2016
# 3       27869/18/16007-ИП от 04.05.2018
# 4       65669/19/16007-ИП от 05.08.2019
# ...                                 ...
# 26528  128192/18/16018-ИП от 18.12.2018
# 26529   13754/14/16012-ИП от 21.11.2014
# 26530    1333/18/16012-ИП от 01.02.2018
# 26531  135288/19/16006-ИП от 26.09.2018
# 26532  135289/19/16006-ИП от 09.10.2018
#
#                                                   credit  \
# 0                                                    nan
# 1                                                    nan
# 2                                          Задолженность
# 3      Задолженность по кредитным платежам (кроме ипо...
# 4      Задолженность по кредитным платежам (кроме ипо...
# ...                                                  ...
# 26528  Задолженность по кредитным платежам (кроме ипо...
# 26529                                                nan
# 26530                     Госпошлина, присужденная судом
# 26531          Задолженность по платежам за услуги связи
# 26532           Взыскание налогов и сборов, включая пени
#
#                                                  details  \
# 0      Постановление судебного пристава-исполнителя о...
# 1      Постановление судебного пристава-исполнителя о...
# 2      Судебный приказ от 20.11.2015 № 2-1756/15 СУДЕ...
# 3      Исполнительный лист от 14.12.2016 № 2-8350/201...
# 4      Исполнительный лист от 14.12.2016 № 2-8350/201...
# ...                                                  ...
# 26528  Судебный приказ от 05.10.2018 № 2-1102/1/2018 ...
# 26529  Постановление судебного пристава-исполнителя о...
# 26530  Исполнительный лист от 21.04.2017 № 2-19/2017 ...
# 26531  Судебный приказ от 20.11.2017 № 2-1283/17 СУДЕ...
# 26532  Судебный приказ от 20.02.2018 № 2А-110/18 СУДЕ...
#
#                                               department    status  dep_id  \
# 0      Приволжское РОСП г.Казани УФССП России по Респ...  46, 1, 3      45
# 1      Приволжское РОСП г.Казани УФССП России по Респ...  46, 1, 3      45
# 2      Приволжское РОСП г.Казани УФССП России по Респ...  46, 1, 3      45
# 3      Приволжское РОСП г.Казани УФССП России по Респ...  46, 1, 3      45
# 4      Приволжское РОСП г.Казани УФССП России по Респ...  46, 1, 3      45
# ...                                                  ...       ...     ...
# 26528  ОСП по Арскому и Атнинскому районам УФССП Росс...  46, 1, 4      34
# 26529  Аксубаевское РОСП УФССП России по Республике Т...  46, 1, 4      37
# 26530  Аксубаевское РОСП УФССП России по Республике Т...  46, 1, 4      37
# 26531  Ново-Савиновский РОСП г.Казани УФССП России по...  47, 1, 6      36
# 26532  Ново-Савиновский РОСП г.Казани УФССП России по...  47, 1, 6      36
#
#        birthday_digit        number_ip_id number_ip_date  year  \
# 0                True  129954/19/16007-ИП     23.12.2019  2019
# 1                True    9013/20/16007-ИП     03.02.2020  2020
# 2                True   60056/17/16007-ИП     03.10.2016  2016
# 3                True   27869/18/16007-ИП     04.05.2018  2018
# 4                True   65669/19/16007-ИП     05.08.2019  2019
# ...               ...                 ...            ...   ...
# 26528            True  128192/18/16018-ИП     18.12.2018  2018
# 26529            True   13754/14/16012-ИП     21.11.2014  2014
# 26530            True    1333/18/16012-ИП     01.02.2018  2018
# 26531            True  135288/19/16006-ИП     26.09.2018  2018
# 26532            True  135289/19/16006-ИП     09.10.2018  2018
#
#                   uniq_details  \
# 0      Постановление судебного
# 1      Постановление судебного
# 2              Судебный приказ
# 3          Исполнительный лист
# 4          Исполнительный лист
# ...                        ...
# 26528          Судебный приказ
# 26529  Постановление судебного
# 26530      Исполнительный лист
# 26531          Судебный приказ
# 26532          Судебный приказ
#
#                                              credit_type sum_rub ip_sum  \
# 0                                                    nan     NaN    NaN
# 1                                                    nan     NaN    NaN
# 2                                          Задолженность     NaN    NaN
# 3      Задолженность по кредитным платежам (кроме ипо...     NaN    NaN
# 4      Задолженность по кредитным платежам (кроме ипо...     NaN    NaN
# ...                                                  ...     ...    ...
# 26528  Задолженность по кредитным платежам (кроме ипо...     NaN    NaN
# 26529                                                nan     NaN    NaN
# 26530                     Госпошлина, присужденная судом     NaN    NaN
# 26531          Задолженность по платежам за услуги связи     NaN    NaN
# 26532           Взыскание налогов и сборов, включая пени     NaN    NaN
#
#        status_id
# 0              4
# 1              4
# 2              4
# 3              4
# 4              4
# ...          ...
# 26528          2
# 26529          2
# 26530          2
# 26531          3
# 26532          3
#
# [26533 rows x 20 columns]

# %%
# get finish datasets : 
# FINISH TABLE for ANALYSIS: number_ip_id, number_ip_date, year, birthday, hometown, dep_id,uniq_details, credit_type,sum_rub,ip_sum,status_id
finish_table = pd.DataFrame({
    'number_ip_id':db['number_ip_id'], 
    'number_ip_date': db['number_ip_date'],
    'year': db['year'],
    'birthday': db['birthday'],
    'hometown': db['hometown'],
    'dep_id': db['dep_id'],
    'uniq_details': db['uniq_details'],
    'credit_type': db['credit_type'],
    'sum_rub': db['sum_rub'],
    'ip_sum': db['ip_sum'],
    'status_id': db['status_id'],
    })
finish_table.to_excel('finish_table.xlsx')

# DIM STATUS: status_id, status
status_ds.to_excel('dim_status.xlsx')

# DIM DEPARTMENT: dep_id, department
deps_ds.to_excel('dim_department.xlsx')

#DIM IP
dim_ip = pd.DataFrame({
    'number_ip_id':db['number_ip_id'], 
    'number_ip': db['number_ip'],
    'name': db['name'],
    'lastname': db['lastname'],
    'secondname': db['secondname'],
    'credit': db['credit'],
    'details': db['details'],
    })
dim_ip.to_excel('dim_ip.xlsx')
